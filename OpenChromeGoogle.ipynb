# %% [markdown]
# # Prueba de abrir google con Selenium en Chrome

# %%
from selenium import webdriver
with webdriver.Chrome() as driver:
    driver.get('https://google.com/')
    import time
 # Wait for 5 seconds
    time.sleep(5)
    driver.close()

# %%
from IPython.display import Image
Image("chrome.jpg")
