# %% [markdown]
# # Prueba Selenium con Firefox abriendo Google

# %%
from selenium import webdriver
with webdriver.Firefox() as driver:
    driver.get('https://google.com/')
    import time
 # Wait for 5 seconds
    time.sleep(5)
    driver.close()
    
from IPython.display import Image
Image("ff.jpg")
